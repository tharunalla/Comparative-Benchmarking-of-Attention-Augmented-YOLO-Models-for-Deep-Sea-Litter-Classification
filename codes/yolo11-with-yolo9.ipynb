# %%
# %cd /kaggle/input/attention_of_yolo9/pytorch/default/1/ultralytics-main
# Out:
# /kaggle/input/attention_of_yolo9/pytorch/default/1/ultralytics-main

# %%
# !cp -r /kaggle/input/attention_of_yolo9/pytorch/default/1/ultralytics-main /kaggle/working/ultralytics-main

# %%
# %cd /kaggle/working/ultralytics-main
# Out:
# /kaggle/working/ultralytics-main

# %%
# !pip install -e .
# Out:
# Obtaining file:///kaggle/working/ultralytics-main
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.0 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 67.6 MB/s eta 0:00:00:00:0100:01
# ...
#   Building editable for ultralytics (pyproject.toml) ... done
# ...

# %%
from ultralytics import YOLO

model = YOLO("/kaggle/input/attention_of_yolo9/pytorch/default/1/ultralytics-main/ultralytics/cfg/models/11/yolo11.yaml").load("yolo11s.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# ...
# 100%|██████████| 18.4M/18.4M [00:00<00:00, 164MB/s]
# Transferred 107/757 items from pretrained weights

# %%
model.train(
    data="/kaggle/input/pathed/data.yaml",
    epochs=300,
    batch=16,
    imgsz=416,
    save=True,
    patience=300,
    val=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.129 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.117 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
